# %%
import glob, os
import pandas as pd
import numpy as np

# %%
path = '../ebikes/data/datatest/'
all_files = glob.glob(os.path.join(path, "*.csv"))

# %%
#print (all_files)
#print (type(all_files[0][-18:-4]))

# %%
df = pd.DataFrame()
#df = pd.concat((pd.read_csv(f) for f in all_files))

for f in all_files:
    _df = pd.read_csv(f)
    _temps = f[-18:-4]
    _df['date'] = pd.Series([pd.Timestamp(_temps)] * len(_df))
    
    _df = _df[['date','vehicleRegistration','lat', 'lon', 'charge']]
    _df = _df.rename(columns={'vehicleRegistration': 'plate'})
    
    df = pd.concat([df,_df])

# %% [markdown]
# ### Sorting and cleaning index

# %%
sorteddf = df.sort_values('date')
sorteddf = sorteddf.reset_index().drop(columns= ['index'])

# %% [markdown]
# ### Writing backup file w/ full df

# %%
sorteddf.to_csv('../ebikes/data/datatest/final/muving_data1.csv', header='column_names', index=False)
sorteddf.head()
# Out:
#                  date                  plate        lat       lon  charge
# 0 2018-09-13 14:21:26  7277KFP Scooter 125-B  41.391782  2.182641      77
# 1 2018-09-13 14:21:26  0900KFT Scooter 125-B  41.393072  2.170602      51
# 2 2018-09-13 14:21:26  5013KFS Scooter 125-B  41.419682  2.172684      79
# 3 2018-09-13 14:21:26  4726KFS Scooter 125-B  41.372394  2.131529      42
# 4 2018-09-13 14:21:26  4548KFS Scooter 125-B  41.401481  2.124199      50

# %%
sorteddf.tail()
# Out:
#                      date                  plate        lat       lon  charge
# 46534 2018-09-21 00:53:13  2328KFM Scooter 125-B  41.389588  2.117397      89
# 46535 2018-09-21 00:53:13  7492KFL Scooter 125-B  41.414405  2.165133      94
# 46536 2018-09-21 00:53:13  7459KFL Scooter 125-B  41.425798  2.149755      38
# 46537 2018-09-21 00:53:13  7554KFL Scooter 125-B  41.360827  2.135152      61
# 46538 2018-09-21 00:53:13  5793KGY Scooter 125-B  41.426862  2.182446      63

# %%
sorteddf.loc[sorteddf['plate'] == '7492KFL Scooter 125-B']
for
# Out:
#                      date                  plate        lat       lon  charge
# 72    2018-09-13 14:21:26  7492KFL Scooter 125-B  41.427656  2.173337      60
# 369   2018-09-13 14:32:17  7492KFL Scooter 125-B  41.427656  2.173337      60
# 503   2018-09-13 14:43:07  7492KFL Scooter 125-B  41.427656  2.173337      60
# 849   2018-09-13 14:53:59  7492KFL Scooter 125-B  41.427656  2.173337      60
# 1123  2018-09-13 15:15:39  7492KFL Scooter 125-B  41.437079  2.158824      56
# 1316  2018-09-13 15:26:29  7492KFL Scooter 125-B  41.437079  2.158824      56
# 1519  2018-09-13 15:37:19  7492KFL Scooter 125-B  41.437079  2.158824      56
# 1778  2018-09-13 15:48:08  7492KFL Scooter 125-B  41.437079  2.158824      56
# 2093  2018-09-13 15:58:56  7492KFL Scooter 125-B  41.437079  2.158824      56
# 2146  2018-09-13 16:09:44  7492KFL Scooter 125-B  41.437079  2.158824      56
# 2346  2018-09-13 16:20:32  7492KFL Scooter 125-B  41.437079  2.158824      56
# 35968 2018-09-20 16:01:29  7492KFL Scooter 125-B  41.398233  2.175525      21
# 36285 2018-09-20 16:12:23  7492KFL Scooter 125-B  41.398233  2.175525      21
# 36562 2018-09-20 16:23:17  7492KFL Scooter 125-B  41.398233  2.175525      21
# 36793 2018-09-20 16:34:07  7492KFL Scooter 125-B  41.398233  2.175525      21
# 36858 2018-09-20 16:44:56  7492KFL Scooter 125-B  41.398233  2.175525      21
# 44502 2018-09-20 23:15:08  7492KFL Scooter 125-B  41.414405  2.165133      94
# 44564 2018-09-20 23:25:59  7492KFL Scooter 125-B  41.414405  2.165133      94
# 44851 2018-09-20 23:36:54  7492KFL Scooter 125-B  41.414405  2.165133      94
# 45163 2018-09-20 23:47:48  7492KFL Scooter 125-B  41.414405  2.165133      94
# 45366 2018-09-20 23:58:41  7492KFL Scooter 125-B  41.414405  2.165133      94
# 45597 2018-09-21 00:09:34  7492KFL Scooter 125-B  41.414405  2.165133      94
# 45808 2018-09-21 00:20:30  7492KFL Scooter 125-B  41.414405  2.165133      94
# 45891 2018-09-21 00:31:24  7492KFL Scooter 125-B  41.414405  2.165133      94
# 46105 2018-09-21 00:42:19  7492KFL Scooter 125-B  41.414405  2.165133      94
# 46535 2018-09-21 00:53:13  7492KFL Scooter 125-B  41.414405  2.165133      94
#
# [142 rows x 5 columns]

# %%
i = 0
listaplates = []
for item in sorteddf['plate']:
    listaplates.append(item)
    if i == 5:
        break
    i+=1
print (listaplates)
# Out:
# ['7277KFP Scooter 125-B', '0900KFT Scooter 125-B', '5013KFS Scooter 125-B', '4726KFS Scooter 125-B', '4548KFS Scooter 125-B', '6903KFP Scooter 125-B']

# %% [markdown]
# ## Test Loop checking gone bikes

# %%
gone_bikes = []
for i in sorteddf['plate']:
    if len(sorteddf.loc[sorteddf['plate'] == '8735KFM Scooter 125-B']) < 3:
        gone_bikes.append(i)
    
gone_bikes = set(gone_bikes)       
#print (gone_bikes)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-dc11560c5254> in <module>()
#       1 gone_bikes = []
#       2 for i in sorteddf['plate']:
# ----> 3     if len(sorteddf.loc[sorteddf['plate'] == '8735KFM Scooter 125-B']) < 3:
#       4         gone_bikes.append(i)
#       5
#
# /anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# /anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#    1141
#    1142         elif is_object_dtype(x.dtype):
# -> 1143             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1144
#    1145         elif is_datetimelike_v_numeric(x, y):
#
# /anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1120         result = libops.vec_compare(x, y, op)
#    1121     else:
# -> 1122         result = libops.scalar_compare(x, y, op)
#    1123     return result
#    1124
#
# KeyboardInterrupt:
